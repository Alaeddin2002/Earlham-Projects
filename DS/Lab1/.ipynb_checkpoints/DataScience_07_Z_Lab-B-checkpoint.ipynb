# %% [markdown]
# # Data Science
# #### By: Javier Orduz
# [license-badge]: https://img.shields.io/badge/License-CC-orange
# [license]: https://creativecommons.org/licenses/by-nc-sa/3.0/deed.en
#
# [![CC License][license-badge]][license]  [![DS](https://img.shields.io/badge/downloads-DS-green)](https://github.com/Earlham-College/DS_Fall_2022)  [![Github](https://img.shields.io/badge/jaorduz-repos-blue)](https://github.com/jaorduz/)  ![Follow @jaorduc](https://img.shields.io/twitter/follow/jaorduc?label=follow&logo=twitter&logoColor=lkj&style=plastic)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv("drinks.csv")

# %%
wine = 0
number = 0
for i in range(len(df["continent"])):
    if df["continent"][i] == "NA":
        wine += df["wine_servings"][i]
        number +=1

if number == 0:
    print (0)
else:
     print(wine/number)
# Out:
# 0

# %%
wine = 0
people = 0
number = 0
for i in range(len(df["continent"])):
    if df["continent"][i] == "SA":
        wine += df["wine_servings"][i]
        people += df["spirit_servings"][i] + df["beer_servings"][i] + df["wine_servings"][i]
        number +=1

if number == 0:
    print (0)
else:
     print(wine/people/number)
# Out:
# 0.014766185632047945

# %%
wine = 0
people = 0
number = 0
for i in range(len(df["continent"])):
    if df["continent"][i] == "AS":
        wine += df["wine_servings"][i]
        people += df["spirit_servings"][i] + df["beer_servings"][i] + df["wine_servings"][i]
        number +=1

if number == 0:
    print (0)
else:
     print(wine/people/number)
# Out:
# 0.001926940462852065

# %%
plt.scatter(df['spirit_servings'],df['wine_servings'])

# %%
df.nlargest(10, 'spirit_servings')
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 68              Grenada            199              438             28
# 15              Belarus            142              373             42
# 73                Haiti              1              326              1
# 141  Russian Federation            247              326             73
# 144           St. Lucia            171              315             71
# 72               Guyana             93              302              1
# 155            Slovakia            196              293            116
# 50             Dominica             52              286             26
# 169            Thailand             99              258              1
# 40         Cook Islands              0              254             74
#
#      total_litres_of_pure_alcohol continent
# 68                           11.9       NaN
# 15                           14.4        EU
# 73                            5.9       NaN
# 141                          11.5        AS
# 144                          10.1       NaN
# 72                            7.1        SA
# 155                          11.4        EU
# 50                            6.6       NaN
# 169                           6.4        AS
# 40                            5.9        OC

# %%
ax = df.plot.hist(column=["continent"], by="EU", figsize=(10, 8))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [21], line 1
# ----> 1 ax = df.plot.hist(column=["continent"], by="EU", figsize=(10, 8))
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/plotting/_core.py:1296, in PlotAccessor.hist(self, by, bins, **kwargs)
#    1251 def hist(self, by=None, bins=10, **kwargs):
#    1252     """
#    1253     Draw one histogram of the DataFrame's columns.
#    1254
#    (...)
#    1294         >>> ax = df.plot.hist(bins=12, alpha=0.5)
#    1295     """
# -> 1296     return self(kind="hist", by=by, bins=bins, **kwargs)
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/plotting/_core.py:955, in PlotAccessor.__call__(self, *args, **kwargs)
#     952             label_name = label_kw or data.columns
#     953             data.columns = label_name
# --> 955 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/plotting/_matplotlib/__init__.py:61, in plot(data, kind, **kwargs)
#      59         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61 plot_obj.generate()
#      62 plot_obj.draw()
#      63 return plot_obj.result
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:280, in MPLPlot.generate(self)
#     278 self._compute_plot_data()
#     279 self._setup_subplots()
# --> 280 self._make_plot()
#     281 self._add_table()
#     282 self._make_legend()
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/plotting/_matplotlib/hist.py:92, in HistPlot._make_plot(self)
#      89 if weights is not None and np.ndim(weights) != 1:
#      90     kwds["weights"] = weights[:, i]
# ---> 92 artists = self._plot(ax, y, column_num=i, stacking_id=stacking_id, **kwds)
#      93 self._add_legend_handle(artists[0], label, index=i)
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/plotting/_matplotlib/hist.py:63, in HistPlot._plot(cls, ax, y, style, bins, bottom, column_num, stacking_id, **kwds)
#      61 bottom = bottom + cls._get_stacked_values(ax, stacking_id, base, kwds["label"])
#      62 # ignore style
# ---> 63 n, bins, patches = ax.hist(y, bins=bins, bottom=bottom, **kwds)
#      64 cls._update_stacker(ax, stacking_id, n)
#      65 return patches
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/matplotlib/__init__.py:1361, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1358 @functools.wraps(func)
#    1359 def inner(ax, *args, data=None, **kwargs):
#    1360     if data is None:
# -> 1361         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1363     bound = new_sig.bind(ax, *args, **kwargs)
#    1364     auto_label = (bound.arguments.get(label_namer)
#    1365                   or bound.kwargs.get(label_namer))
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/matplotlib/axes/_axes.py:6911, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6909 if patch:
#    6910     p = patch[0]
# -> 6911     p.update(kwargs)
#    6912     if lbl is not None:
#    6913         p.set_label(lbl)
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/matplotlib/artist.py:1062, in Artist.update(self, props)
#    1060             func = getattr(self, f"set_{k}", None)
#    1061             if not callable(func):
# -> 1062                 raise AttributeError(f"{type(self).__name__!r} object "
#    1063                                      f"has no property {k!r}")
#    1064             ret.append(func(v))
#    1065 if ret:
#
# AttributeError: 'Rectangle' object has no property 'column'

# %%
ax = df.plot.hist(column=["continent"], by="AS", figsize=(10, 8))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [23], line 1
# ----> 1 ax = df.plot.hist(column=["continent"], by="AS", figsize=(10, 8))
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/plotting/_core.py:1296, in PlotAccessor.hist(self, by, bins, **kwargs)
#    1251 def hist(self, by=None, bins=10, **kwargs):
#    1252     """
#    1253     Draw one histogram of the DataFrame's columns.
#    1254
#    (...)
#    1294         >>> ax = df.plot.hist(bins=12, alpha=0.5)
#    1295     """
# -> 1296     return self(kind="hist", by=by, bins=bins, **kwargs)
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/plotting/_core.py:955, in PlotAccessor.__call__(self, *args, **kwargs)
#     952             label_name = label_kw or data.columns
#     953             data.columns = label_name
# --> 955 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/plotting/_matplotlib/__init__.py:61, in plot(data, kind, **kwargs)
#      59         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61 plot_obj.generate()
#      62 plot_obj.draw()
#      63 return plot_obj.result
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:280, in MPLPlot.generate(self)
#     278 self._compute_plot_data()
#     279 self._setup_subplots()
# --> 280 self._make_plot()
#     281 self._add_table()
#     282 self._make_legend()
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/plotting/_matplotlib/hist.py:92, in HistPlot._make_plot(self)
#      89 if weights is not None and np.ndim(weights) != 1:
#      90     kwds["weights"] = weights[:, i]
# ---> 92 artists = self._plot(ax, y, column_num=i, stacking_id=stacking_id, **kwds)
#      93 self._add_legend_handle(artists[0], label, index=i)
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/plotting/_matplotlib/hist.py:63, in HistPlot._plot(cls, ax, y, style, bins, bottom, column_num, stacking_id, **kwds)
#      61 bottom = bottom + cls._get_stacked_values(ax, stacking_id, base, kwds["label"])
#      62 # ignore style
# ---> 63 n, bins, patches = ax.hist(y, bins=bins, bottom=bottom, **kwds)
#      64 cls._update_stacker(ax, stacking_id, n)
#      65 return patches
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/matplotlib/__init__.py:1361, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1358 @functools.wraps(func)
#    1359 def inner(ax, *args, data=None, **kwargs):
#    1360     if data is None:
# -> 1361         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1363     bound = new_sig.bind(ax, *args, **kwargs)
#    1364     auto_label = (bound.arguments.get(label_namer)
#    1365                   or bound.kwargs.get(label_namer))
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/matplotlib/axes/_axes.py:6911, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6909 if patch:
#    6910     p = patch[0]
# -> 6911     p.update(kwargs)
#    6912     if lbl is not None:
#    6913         p.set_label(lbl)
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/matplotlib/artist.py:1062, in Artist.update(self, props)
#    1060             func = getattr(self, f"set_{k}", None)
#    1061             if not callable(func):
# -> 1062                 raise AttributeError(f"{type(self).__name__!r} object "
#    1063                                      f"has no property {k!r}")
#    1064             ret.append(func(v))
#    1065 if ret:
#
# AttributeError: 'Rectangle' object has no property 'column'

# %%
ax = df.plot.hist(column=["continent"], by="OC", figsize=(10, 8))

# %%
ax = df.plot.hist(column=["continent"], by="SA", figsize=(10, 8))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [24], line 1
# ----> 1 ax = df.plot.hist(column=["continent"], by="SA", figsize=(10, 8))
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/plotting/_core.py:1296, in PlotAccessor.hist(self, by, bins, **kwargs)
#    1251 def hist(self, by=None, bins=10, **kwargs):
#    1252     """
#    1253     Draw one histogram of the DataFrame's columns.
#    1254
#    (...)
#    1294         >>> ax = df.plot.hist(bins=12, alpha=0.5)
#    1295     """
# -> 1296     return self(kind="hist", by=by, bins=bins, **kwargs)
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/plotting/_core.py:955, in PlotAccessor.__call__(self, *args, **kwargs)
#     952             label_name = label_kw or data.columns
#     953             data.columns = label_name
# --> 955 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/plotting/_matplotlib/__init__.py:61, in plot(data, kind, **kwargs)
#      59         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61 plot_obj.generate()
#      62 plot_obj.draw()
#      63 return plot_obj.result
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:280, in MPLPlot.generate(self)
#     278 self._compute_plot_data()
#     279 self._setup_subplots()
# --> 280 self._make_plot()
#     281 self._add_table()
#     282 self._make_legend()
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/plotting/_matplotlib/hist.py:92, in HistPlot._make_plot(self)
#      89 if weights is not None and np.ndim(weights) != 1:
#      90     kwds["weights"] = weights[:, i]
# ---> 92 artists = self._plot(ax, y, column_num=i, stacking_id=stacking_id, **kwds)
#      93 self._add_legend_handle(artists[0], label, index=i)
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/plotting/_matplotlib/hist.py:63, in HistPlot._plot(cls, ax, y, style, bins, bottom, column_num, stacking_id, **kwds)
#      61 bottom = bottom + cls._get_stacked_values(ax, stacking_id, base, kwds["label"])
#      62 # ignore style
# ---> 63 n, bins, patches = ax.hist(y, bins=bins, bottom=bottom, **kwds)
#      64 cls._update_stacker(ax, stacking_id, n)
#      65 return patches
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/matplotlib/__init__.py:1361, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1358 @functools.wraps(func)
#    1359 def inner(ax, *args, data=None, **kwargs):
#    1360     if data is None:
# -> 1361         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1363     bound = new_sig.bind(ax, *args, **kwargs)
#    1364     auto_label = (bound.arguments.get(label_namer)
#    1365                   or bound.kwargs.get(label_namer))
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/matplotlib/axes/_axes.py:6911, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6909 if patch:
#    6910     p = patch[0]
# -> 6911     p.update(kwargs)
#    6912     if lbl is not None:
#    6913         p.set_label(lbl)
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/matplotlib/artist.py:1062, in Artist.update(self, props)
#    1060             func = getattr(self, f"set_{k}", None)
#    1061             if not callable(func):
# -> 1062                 raise AttributeError(f"{type(self).__name__!r} object "
#    1063                                      f"has no property {k!r}")
#    1064             ret.append(func(v))
#    1065 if ret:
#
# AttributeError: 'Rectangle' object has no property 'column'

# %%
ax = df.plot.hist(column=["continent"], by="NA", figsize=(10, 8))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [25], line 1
# ----> 1 ax = df.plot.hist(column=["continent"], by="NA", figsize=(10, 8))
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/plotting/_core.py:1296, in PlotAccessor.hist(self, by, bins, **kwargs)
#    1251 def hist(self, by=None, bins=10, **kwargs):
#    1252     """
#    1253     Draw one histogram of the DataFrame's columns.
#    1254
#    (...)
#    1294         >>> ax = df.plot.hist(bins=12, alpha=0.5)
#    1295     """
# -> 1296     return self(kind="hist", by=by, bins=bins, **kwargs)
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/plotting/_core.py:955, in PlotAccessor.__call__(self, *args, **kwargs)
#     952             label_name = label_kw or data.columns
#     953             data.columns = label_name
# --> 955 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/plotting/_matplotlib/__init__.py:61, in plot(data, kind, **kwargs)
#      59         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61 plot_obj.generate()
#      62 plot_obj.draw()
#      63 return plot_obj.result
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:280, in MPLPlot.generate(self)
#     278 self._compute_plot_data()
#     279 self._setup_subplots()
# --> 280 self._make_plot()
#     281 self._add_table()
#     282 self._make_legend()
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/plotting/_matplotlib/hist.py:92, in HistPlot._make_plot(self)
#      89 if weights is not None and np.ndim(weights) != 1:
#      90     kwds["weights"] = weights[:, i]
# ---> 92 artists = self._plot(ax, y, column_num=i, stacking_id=stacking_id, **kwds)
#      93 self._add_legend_handle(artists[0], label, index=i)
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/plotting/_matplotlib/hist.py:63, in HistPlot._plot(cls, ax, y, style, bins, bottom, column_num, stacking_id, **kwds)
#      61 bottom = bottom + cls._get_stacked_values(ax, stacking_id, base, kwds["label"])
#      62 # ignore style
# ---> 63 n, bins, patches = ax.hist(y, bins=bins, bottom=bottom, **kwds)
#      64 cls._update_stacker(ax, stacking_id, n)
#      65 return patches
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/matplotlib/__init__.py:1361, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1358 @functools.wraps(func)
#    1359 def inner(ax, *args, data=None, **kwargs):
#    1360     if data is None:
# -> 1361         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1363     bound = new_sig.bind(ax, *args, **kwargs)
#    1364     auto_label = (bound.arguments.get(label_namer)
#    1365                   or bound.kwargs.get(label_namer))
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/matplotlib/axes/_axes.py:6911, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6909 if patch:
#    6910     p = patch[0]
# -> 6911     p.update(kwargs)
#    6912     if lbl is not None:
#    6913         p.set_label(lbl)
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/matplotlib/artist.py:1062, in Artist.update(self, props)
#    1060             func = getattr(self, f"set_{k}", None)
#    1061             if not callable(func):
# -> 1062                 raise AttributeError(f"{type(self).__name__!r} object "
#    1063                                      f"has no property {k!r}")
#    1064             ret.append(func(v))
#    1065 if ret:
#
# AttributeError: 'Rectangle' object has no property 'column'

# %%
ax = df.plot.hist(column=["continent"], by="Nan", figsize=(10, 8))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [22], line 1
# ----> 1 ax = df.plot.hist(column=["continent"], by="Nan", figsize=(10, 8))
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/plotting/_core.py:1296, in PlotAccessor.hist(self, by, bins, **kwargs)
#    1251 def hist(self, by=None, bins=10, **kwargs):
#    1252     """
#    1253     Draw one histogram of the DataFrame's columns.
#    1254
#    (...)
#    1294         >>> ax = df.plot.hist(bins=12, alpha=0.5)
#    1295     """
# -> 1296     return self(kind="hist", by=by, bins=bins, **kwargs)
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/plotting/_core.py:955, in PlotAccessor.__call__(self, *args, **kwargs)
#     952             label_name = label_kw or data.columns
#     953             data.columns = label_name
# --> 955 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/plotting/_matplotlib/__init__.py:61, in plot(data, kind, **kwargs)
#      59         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61 plot_obj.generate()
#      62 plot_obj.draw()
#      63 return plot_obj.result
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:280, in MPLPlot.generate(self)
#     278 self._compute_plot_data()
#     279 self._setup_subplots()
# --> 280 self._make_plot()
#     281 self._add_table()
#     282 self._make_legend()
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/plotting/_matplotlib/hist.py:92, in HistPlot._make_plot(self)
#      89 if weights is not None and np.ndim(weights) != 1:
#      90     kwds["weights"] = weights[:, i]
# ---> 92 artists = self._plot(ax, y, column_num=i, stacking_id=stacking_id, **kwds)
#      93 self._add_legend_handle(artists[0], label, index=i)
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/plotting/_matplotlib/hist.py:63, in HistPlot._plot(cls, ax, y, style, bins, bottom, column_num, stacking_id, **kwds)
#      61 bottom = bottom + cls._get_stacked_values(ax, stacking_id, base, kwds["label"])
#      62 # ignore style
# ---> 63 n, bins, patches = ax.hist(y, bins=bins, bottom=bottom, **kwds)
#      64 cls._update_stacker(ax, stacking_id, n)
#      65 return patches
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/matplotlib/__init__.py:1361, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1358 @functools.wraps(func)
#    1359 def inner(ax, *args, data=None, **kwargs):
#    1360     if data is None:
# -> 1361         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1363     bound = new_sig.bind(ax, *args, **kwargs)
#    1364     auto_label = (bound.arguments.get(label_namer)
#    1365                   or bound.kwargs.get(label_namer))
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/matplotlib/axes/_axes.py:6911, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6909 if patch:
#    6910     p = patch[0]
# -> 6911     p.update(kwargs)
#    6912     if lbl is not None:
#    6913         p.set_label(lbl)
#
# File /mounts/bowie/software/anaconda3/envs/py39/lib/python3.9/site-packages/matplotlib/artist.py:1062, in Artist.update(self, props)
#    1060             func = getattr(self, f"set_{k}", None)
#    1061             if not callable(func):
# -> 1062                 raise AttributeError(f"{type(self).__name__!r} object "
#    1063                                      f"has no property {k!r}")
#    1064             ret.append(func(v))
#    1065 if ret:
#
# AttributeError: 'Rectangle' object has no property 'column'

# %%
wine = 0
number = 0
for i in range(len(df["continent"])):
    if df["continent"][i] == "SA":
        wine += df["wine_servings"][i]
        number +=1

if number == 0:
    print (0)
else:
     print(wine/number)
# Out:
# 62.416666666666664

# %%
wine = 0
number = 0
for i in range(len(df["continent"])):
    if df["continent"][i] == "EU":
        wine += df["wine_servings"][i]
        number +=1

if number == 0:
    print (0)
else:
     print(wine/number)
# Out:
# 142.22222222222223

# %%
wine = 0
number = 0
for i in range(len(df["continent"])):
    if df["continent"][i] == "AS":
        wine += df["wine_servings"][i]
        number +=1

if number == 0:
    print (0)
else:
     print(wine/number)
# Out:
# 9.068181818181818

# %%
wine = 0
number = 0
for i in range(len(df["continent"])):
    if df["continent"][i] == "NA":
        wine += df["wine_servings"][i]
        number +=1

if number == 0:
    print (0)
else:
     print(wine/number)
# Out:
# 0

# %%
df.groupby(['continent']).mean()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF             61.471698        16.339623      16.264151
# AS             37.045455        60.840909       9.068182
# EU            193.777778       132.555556     142.222222
# OC             89.687500        58.437500      35.625000
# SA            175.083333       114.750000      62.416667
#
#            total_litres_of_pure_alcohol
# continent
# AF                             3.007547
# AS                             2.170455
# EU                             8.617778
# OC                             3.381250
# SA                             6.308333

# %% [markdown]
# # Exercises

# %% [markdown]
# 1. Use ```pandas``` and read dataset drinks.csv
# 1. What is the average wine consumption per person per year in North America?
# 1. What is the average wine consumption per person per year in South America?
# 1. What is the average wine consumption per person per year in Asia?
# 1. Create a scatter plot between spirit servings and wine servings of all countries.
# 1. Show a list of the top 10 spirit drinking countries: show country names & spirit servings.
# 1. Plot 6 histograms of wine servings by continent.
# 1. What is the average wine consumption in South America?
# 1. What is the average wine consumption in Europe?
# 1. What is the average wine consumption in Asia?
# 1. What is the average wine consumption in North America?
# 1. Which continent has the highest on average wine consumption?
#
# 1. Submmit your report in Moodle. Template https://www.overleaf.com/read/xqcnnnrsspcp

# %% [markdown]
# ## Versions

# %%
from platform import python_version
print("python version: ", python_version())
# !pip3 freeze | grep qiskit

# %% [markdown]
# # References

# %% [markdown]
# [0] source https://github.com/sinanuozdemir
#
# [1] numpy https://numpy.org/
#
# [2] scipy https://docs.scipy.org/
#
# [3] matplotlib https://matplotlib.org/
#
# [4] matplotlib.cm https://matplotlib.org/stable/api/cm_api.html
#
# [5] matplotlib.pyplot https://matplotlib.org/stable/api/pyplot_summary.html
#
# [6] pandas https://pandas.pydata.org/docs/
#
# [7] seaborn https://seaborn.pydata.org/
