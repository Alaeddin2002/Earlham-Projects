# %%
from sympy import *

y= symbols('y')

expression = ((y*(1+y))/(y*(-y**2+y)))

print(expression)
# Out:
# (y + 1)/(-y**2 + y)

# %%
a = 8
b = 2
x = log (a,b)
print (x)
# Out:
# 3

# %%
x= symbols('x')
f = ((1+(1/x))**x)
result = limit(f,x,10)
result2 = limit(f,x,100)
result3 = limit(f,x,1000)
print(result,result2,result3)
# Out:
# E ... ...
