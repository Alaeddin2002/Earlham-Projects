# %%
slots = {"1":"","2":"", "3":"", "4":"", "5":"", "6":"", "7":"", "8":"", "9":"" }
Board_list= []
for key in slots:
    Board_list.append(key)

def theBoard(Board):
    print ("The Board is:")
    print(slots["1"] + "_|" + slots["2"] + "_|" + slots["3"] + "_")
    print(slots["4"] + "_|" + slots["5"] + "_|" + slots["6"] + "_")
    print(slots["7"]  + " |" + slots["8"] + " |" + slots["9"] )
   
    
import random
def Tic_Tac_Toe():
    print ("Rules as are follow:")
    print ("")
    print ("1. You choose a symbol to play as")
    print ("")
    print ("2. The aim of the game is to get your symbol in 3 slots that are next to each other")
    print ("")
    print ("3. The 3 slots can be horizontal, vertical, or sideways ")
    print ("")
    print ("4. Computer's Symbol is O ")
    print ("")
    print ("Slots are arranges as:")
    print ("_1|_2_|3_")
    print ("_4|_5_|6_" )
    print ("_7|_8_|9_" )
    print ("" )
    print ("The Board is:")
    print ("")
    
    symbol =(input("Which Symbol will you use?"))
    print ("")
    print("Your Symbol is:",symbol)
    choice = input("Where do you want your symbol to be?")
    choice_2= str(choice)
    print ("")
    computer = random.choice(slots)
    
    for i in range(10):
        theBoard(Board)
        print("It's your turn," + turn + ".Move to which place?")
        if slots[choice_2] == ' ':
            slots[choice_2] = computer
            count += 1
        elif slots[choice_2] != ' ':
            print("That place is already filled.\nMove to which place?")
            continue
       
        if computer >= 5:
            if slots['7'] == slots['8'] == slots['9'] != ' ': 
                print (theBoard(Board))
                print("\nGame Over.\n")                
                print(" **** " +turn + " won. ****")                
                break
            elif slots['4'] == slots['5'] == slots['6'] != ' ': 
                print (theBoard(Board))             
                print("\nGame Over.\n")                
                print(" **** " +turn + " won. ****")
                break
            elif slots['1'] == slots['2'] == slots['3'] != ' ': 
                print (theBoard(Board))
                print("\nGame Over.\n")                
                print(" **** " +turn + " won. ****")
                break
            elif slots['1'] == slots['4'] == slots['7'] != ' ': 
                print (theBoard(Board))
                print("\nGame Over.\n")                
                print(" **** " +turn + " won. ****")
                break
            elif slots['2'] == slots['5'] == slots['8'] != ' ': 
                print (theBoard(Board))
                print("\nGame Over.\n")                
                print(" **** " +turn + " won. ****")
                break
            elif slots['3'] == slots['6'] == slots['9'] != ' ': 
                print (theBoard(Board))
                print("\nGame Over.\n")                
                print(" **** " +turn + " won. ****")
                break 
            elif slots['7'] == slots['5'] == slots['3'] != ' ': 
                print (theBoard(Board))
                print("\nGame Over.\n")                
                print(" **** " +turn + " won. ****")
                break
            elif slots['1'] == slots['5'] == slots['9'] != ' ': 
                print (theBoard(Board))
                print("\nGame Over.\n")                
                print(" **** " +turn + " won. ****")
                break 
            if count == 9:
                print("\nGame Over.\n")                
                print("It's a Tie!!")
        
    

    
Tic_Tac_Toe()
# Out:
# Rules as are follow:
#
# 1. You choose a symbol to play as
#
# 2. The aim of the game is to get your symbol in 3 slots that are next to each other
#
# 3. The 3 slots can be horizontal, vertical, or sideways
#
# 4. Computer's Symbol is O
#
# Slots are arranges as:
# _1|_2_|3_
# _4|_5_|6_
# _7|_8_|9_
#
# The Board is:
#
# Which Symbol will you use?x
#
# Your Symbol is: x
# Where do you want your symbol to be?1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-2bb00ef1fd99> in <module>
#     108
#     109
# --> 110 Tic_Tac_Toe()
#
# <ipython-input-8-2bb00ef1fd99> in Tic_Tac_Toe()
#      37     choice_2= str(choice)
#      38     print ("")
# ---> 39     computer = random.choice(slots)
#      40
#      41     for i in range(10):
#
# /mounts/bowie/software/anaconda3/lib/python3.7/random.py in choice(self, seq)
#     260         except ValueError:
# ...
