# %%
def proof():
    for i in range (0,1000):
        M = 2**i - 1
        if is_prime(M) == True:
            print()
            print("M is", M,"when p is", i )
            print(is_prime(M),",", M ,"Is a Prime Number")
            print(is_prime(i),",", i ,"Is a Prime Number")

proof()
# Out:
# M is 3 when p is 2
# True , 3 Is a Prime Number
# True , 2 Is a Prime Number
#
# M is 7 when p is 3
# True , 7 Is a Prime Number
# True , 3 Is a Prime Number
#
# M is 31 when p is 5
# True , 31 Is a Prime Number
# True , 5 Is a Prime Number
#
# M is 127 when p is 7
# True , 127 Is a Prime Number
# True , 7 Is a Prime Number
#
# M is 8191 when p is 13
# True , 8191 Is a Prime Number
# True , 13 Is a Prime Number
#
# M is 131071 when p is 17
# True , 131071 Is a Prime Number
# True , 17 Is a Prime Number
#
# M is 524287 when p is 19
# True , 524287 Is a Prime Number
# True , 19 Is a Prime Number
#
# M is 2147483647 when p is 31
# True , 2147483647 Is a Prime Number
# True , 31 Is a Prime Number
#
# M is 2305843009213693951 when p is 61
# True , 2305843009213693951 Is a Prime Number
# True , 61 Is a Prime Number
#
# M is 618970019642690137449562111 when p is 89
# True , 618970019642690137449562111 Is a Prime Number
# True , 89 Is a Prime Number
#
# ...

# %%
def proof_2(p):
    M = 2**p - 1
    D = 2**(p-1)
    l = []
    if is_prime(M) == True:
        c = D * M
        for i in range (1,c):
            if c%i == 0:
                l.append(i)
        print(c)
        print(l)
        print('the sum of the factors of', c, 'is' ,sum(l))
        print('meaning it is a perfect even number, as it is also divisable by 2')
proof_2(3)
# Out:
# 28
# [1, 2, 4, 7, 14]
# the sum of the factors of 28 is 28
# meaning it is a perfect even number, as it is also divisable by 2

# %%
def proof_3():
    
    for p in range (100):
        if is_prime(p) is True:
            print('p is', p)
            M = 2**p - 1
            print("The Merssene Prime is", M)
            for i in range (1,M+1):
                if M % i == 0 and is_prime(i) == True:
                    print("q is", i)
                    if i % 8 == 7 or 1:
                        print("q equals", i%8, "for mod 8")
                        k = (i-1)/(2*p)
                    print("q equals 2kp+1 for integer k", k)
                    print()
        
    
proof_3()
# Out:
# p is 2
# The Merssene Prime is 3
# q is 3
# q equals 3 for mod 8
# q equals 2kp+1 for integer 1/2
#
# p is 3
# The Merssene Prime is 7
# q is 7
# q equals 7 for mod 8
# q equals 2kp+1 for integer 1
#
# p is 5
# The Merssene Prime is 31
# q is 31
# q equals 7 for mod 8
# q equals 2kp+1 for integer 3
#
# p is 7
# The Merssene Prime is 127
# q is 127
# q equals 7 for mod 8
# q equals 2kp+1 for integer 9
#
# p is 11
# The Merssene Prime is 2047
# q is 23
# q equals 7 for mod 8
# q equals 2kp+1 for integer 1
#
# q is 89
# q equals 1 for mod 8
# q equals 2kp+1 for integer 4
#
# p is 13
# The Merssene Prime is 8191
# q is 8191
# q equals 7 for mod 8
# q equals 2kp+1 for integer 315
#
# p is 17
# The Merssene Prime is 131071
# q is 131071
# q equals 7 for mod 8
# q equals 2kp+1 for integer 3855
#
# p is 19
# The Merssene Prime is 524287
# q is 524287
# q equals 7 for mod 8
# q equals 2kp+1 for integer 13797
#
# p is 23
# The Merssene Prime is 8388607
# q is 47
# q equals 7 for mod 8
# ...

# %%
def proof_4():
    for p in range (1,100000):
        if p%4 == 3 and is_prime(p) is True:
            print(p)
        M = 2**p - 1
        if M % (2*p+1) == 0:
            print ((2*p+1).is_prime(),(2*p+1), "is prime")
            print()
proof_4()
# Out:
# 3
# True 7 is prime
#
# 7
# True 17 is prime
#
# 11
# True 23 is prime
#
# True 31 is prime
#
# 19
# True 41 is prime
#
# 23
# True 47 is prime
#
# 31
# True 71 is prime
#
# True 73 is prime
#
# True 79 is prime
#
# 43
# True 89 is prime
#
# 47
# True 97 is prime
#
# True 103 is prime
#
# True 113 is prime
#
# 59
# True 127 is prime
#
# 67
# True 137 is prime
#
# 71
# True 151 is prime
#
# 79
# 83
# True 167 is prime
#
# True 191 is prime
#
# True 193 is prime
#
# True 199 is prime
#
# 103
# 107
# True 223 is prime
#
# True 233 is prime
#
# True 239 is prime
#
# True 241 is prime
#
# 127
# True 257 is prime
#
# 131
# True 263 is prime
#
# True 271 is prime
#
# 139
# True 281 is prime
#
# 151
# True 311 is prime
#
# True 313 is prime
#
# 163
# 167
# True 337 is prime
#
# False 341 is prime
#
# True 353 is prime
#
# 179
# True 359 is prime
#
# True 367 is prime
#
# 191
# True 383 is prime
#
# 199
# True 401 is prime
#
# True 409 is prime
#
# 211
# True 431 is prime
#
# ...

# %%
def proof_5(q):
    
    if is_prime(q) is True:
        M = 2**q - 1
        D = 2**(q-1)
        
    p = M * D
    c = p
    l = []
    d = 0
    for i in range (1,p):
        if p%i == 0:
            l.append(i)
    if p == sum(l):    
        print("the starting perfect even number is", p)
        while c !=1:
            for i in str(c):
                d += int(i)
            c = d
            print(c)
            d = 0
    
    print(l)
    print('the sum of the factors of', p, 'is' ,sum(l))
    print('meaning it is a perfect even number, as it is also divisable by 2')
proof_5(3)
# Out:
# the starting perfect even number is 28
# 10
# 1
# [1, 2, 4, 7, 14]
# the sum of the factors of 28 is 28
# meaning it is a perfect even number, as it is also divisable by 2

# %%
def lucas_lehmer():
    a = time.time()
    l = [ 2, 3, 5, 7, 13, 17, 19, 31, 61, 89, 107, 127, 521, 607, 1279, 2203, 
         2281, 3217, 4253,4423,9689, 9941, 11213, 19937, 21701, 23209, 44497, 86243, 110503, 132049]
    for x in l:
        M = 2**x - 1
        s = 4
        for i in range(x-2):
            s = (s*s - 2) % M
            if s == 0:
                print(s == 0,",", x, 'gives a Prime Mersenne Number',flush = True)
                b = time.time()
                print(b-a,flush = True)
lucas_lehmer()
# Out:
# True , 3 is a Mersenne Number
# 0.0014693737030029297
# True , 5 is a Mersenne Number
# 0.0028553009033203125
# True , 7 is a Mersenne Number
# 0.004122495651245117
# True , 13 is a Mersenne Number
# 0.005279541015625
# True , 17 is a Mersenne Number
# 0.006552696228027344
# True , 19 is a Mersenne Number
# 0.007819414138793945
# True , 31 is a Mersenne Number
# 0.009055376052856445
# True , 61 is a Mersenne Number
# 0.010350227355957031
# True , 89 is a Mersenne Number
# 0.011658430099487305
# True , 107 is a Mersenne Number
# 0.013232707977294922
# True , 127 is a Mersenne Number
# 0.014588356018066406
# True , 521 is a Mersenne Number
# 0.017029762268066406
# True , 607 is a Mersenne Number
# 0.019819259643554688
# True , 1279 is a Mersenne Number
# 0.02604389190673828
# True , 2203 is a Mersenne Number
# 0.05055427551269531
# True , 2281 is a Mersenne Number
# 0.06413698196411133
# True , 3217 is a Mersenne Number
# 0.09269142150878906
# True , 4253 is a Mersenne Number
# ...

# %%
def Mersenne ():
    for i in range (1,100):
        M = 2**i - 1
        if is_prime(M) != True:
            d = []
            for r in range(1,M+1):
                if M%r == 0:
                    d.append(r)
            print("M is", M,"when p is", i )
            print("factors of the Mersenne Numbers are",d)
            print()         
Mersenne ()
# Out:
# M is 0 when p is 0
# factors of the Mersenne Numbers are []
#
# M is 1 when p is 1
# factors of the Mersenne Numbers are [1]
#
# M is 15 when p is 4
# factors of the Mersenne Numbers are [1, 3, 5, 15]
#
# M is 63 when p is 6
# factors of the Mersenne Numbers are [1, 3, 7, 9, 21, 63]
#
# M is 255 when p is 8
# factors of the Mersenne Numbers are [1, 3, 5, 15, 17, 51, 85, 255]
#
# M is 511 when p is 9
# factors of the Mersenne Numbers are [1, 7, 73, 511]
#
# M is 1023 when p is 10
# factors of the Mersenne Numbers are [1, 3, 11, 31, 33, 93, 341, 1023]
#
# M is 2047 when p is 11
# factors of the Mersenne Numbers are [1, 23, 89, 2047]
#
# M is 4095 when p is 12
# factors of the Mersenne Numbers are [1, 3, 5, 7, 9, 13, 15, 21, 35, 39, 45, 63, 65, 91, 105, 117, 195, 273, 315, 455, 585, 819, 1365, 4095]
#
# M is 16383 when p is 14
# factors of the Mersenne Numbers are [1, 3, 43, 127, 129, 381, 5461, 16383]
#
# M is 32767 when p is 15
# ...

# %%
def Mersenne_1 ():
    for i in range (1,1000):
        M = 2**i - 1
        if is_prime(M) != True:
            v = M.factor()
            print("M is", M,"when p is", i )
            print("factors of the Mersenne Numbers are",v)
            print()         
Mersenne_1 ()
# Out:
# M is 1 when p is 1
# factors of the Mersenne Numbers are 1
#
# M is 15 when p is 4
# factors of the Mersenne Numbers are 3 * 5
#
# M is 63 when p is 6
# factors of the Mersenne Numbers are 3^2 * 7
#
# M is 255 when p is 8
# factors of the Mersenne Numbers are 3 * 5 * 17
#
# M is 511 when p is 9
# factors of the Mersenne Numbers are 7 * 73
#
# M is 1023 when p is 10
# factors of the Mersenne Numbers are 3 * 11 * 31
#
# M is 2047 when p is 11
# factors of the Mersenne Numbers are 23 * 89
#
# M is 4095 when p is 12
# factors of the Mersenne Numbers are 3^2 * 5 * 7 * 13
#
# M is 16383 when p is 14
# factors of the Mersenne Numbers are 3 * 43 * 127
#
# M is 32767 when p is 15
# factors of the Mersenne Numbers are 7 * 31 * 151
#
# M is 65535 when p is 16
# factors of the Mersenne Numbers are 3 * 5 * 17 * 257
#
# M is 262143 when p is 18
# factors of the Mersenne Numbers are 3^3 * 7 * 19 * 73
#
# M is 1048575 when p is 20
# factors of the Mersenne Numbers are 3 * 5^2 * 11 * 31 * 41
#
# ...
