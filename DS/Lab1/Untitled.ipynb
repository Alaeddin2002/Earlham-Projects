# %%
import matplotlib.pyplot as plt
import math
import pandas as pd
import pylab as pl
import numpy as np
import io
from sklearn import linear_model
regr = linear_model.LinearRegression()
# %matplotlib inline

df = pd.read_csv("drinks.csv",encoding = 'latin1')
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
df.dtypes
cdf = df[["country","beer_servings","spirit_servings","wine_servings","total_litres_of_pure_alcohol","continent"]]

# %%
msk = np.random.rand(len(df)) < 0.7
set_1 = cdf[msk]
set_2 = cdf[~msk]

# %%
training_data = cdf.sample(frac=0.5, random_state=25)
testing_data = cdf.drop(training_data.index)
training_data.append([101,102])
# Out:
#          0  beer_servings continent     country  spirit_servings  \
# 108    NaN           98.0        AF   Mauritius             31.0
# 82     NaN           63.0        AS      Israel             69.0
# 69     NaN           53.0       NaN   Guatemala             69.0
# 147    NaN            0.0        EU  San Marino              0.0
# 75     NaN          234.0        EU     Hungary            215.0
# ..     ...            ...       ...         ...              ...
# 128    NaN            0.0        AS    Pakistan              0.0
# 27     NaN           88.0        AF     Burundi              0.0
# 126    NaN          169.0        EU      Norway             71.0
# 0    101.0            NaN       NaN         NaN              NaN
# 1    102.0            NaN       NaN         NaN              NaN
#
#      total_litres_of_pure_alcohol  wine_servings
# 108                           2.6           18.0
# 82                            2.5            9.0
# ...

# %%
plt.scatter(df["wine_servings"],df["beer_servings"])
plt.bar((df["continent"]), df["wine_servings"], color ='maroon',
        width = 0.4)
# Out:
# <BarContainer object of 193 artists>
